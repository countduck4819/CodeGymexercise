# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
n=int(input("Nhập vào số n:"))
s=0
a=1
while a<=n:
    s=s+a
    a=a+1
print(s)
# Out:
# Nhập vào số n:132
# 8778

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input("Nhập vào số n:"))
a=1
s=0
while a<=n:
    s=s+a**2
    a=a+1
print(s)
# Out:
# Nhập vào số n:12
# 650

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input("Nhập vào số n:"))
s=0
a=1
for i in range(n):
    if (1/a)>=(1/n):
        s=s+1/a
        a=a+1
print(s)
# Out:
# Nhập vào số n:12
# 3.103210678210678

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input("Nhập vào số n:"))
s=0
a=2
for i in range(n):
    if (1/a)>=(1/(2*n)):
        s=s+1/a
        a=a+2
print(s)
# Out:
# Nhập vào số n:12
# 1.551605339105339

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input("Nhập vào số n:"))
s=1
a=1

for i in range(n):
    if (1/(2*a+1))>=(1/(2*n+1)):
        s=s+1/(2*a+1)
        a=a+1
print(s)
# Out:
# Nhập vào số n:2
# 1.5333333333333332
